# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from skimage.io import imread
import os
from glob import glob
# %matplotlib inline

# %%
#데이터보기
base_bone_dir = os.path.join('..', 'input', 'rsna-bone-age')
age_df = pd.read_csv(os.path.join(base_bone_dir, 'boneage-training-dataset.csv'))
age_df['path'] = age_df['id'].map(lambda x: os.path.join(base_bone_dir,
                                                         'boneage-training-dataset', 
                                                         'boneage-training-dataset', 
                                                         '{}.png'.format(x)))
age_df['exists'] = age_df['path'].map(os.path.exists)
print(age_df['exists'].sum(), 'images found of', age_df.shape[0], 'total')
age_df['gender'] = age_df['male'].map(lambda x: 'male' if x else 'female')
boneage_mean = age_df['boneage'].mean()
boneage_div = 2*age_df['boneage'].std()
boneage_mean = 0
boneage_div = 1.0
age_df['boneage_zscore'] = age_df['boneage'].map(lambda x: (x-boneage_mean)/boneage_div)
age_df.dropna(inplace = True)
age_df.sample(3)
# Out:
# 12611 images found of 12611 total
#         id  boneage   male                                               path  \
# 5124  7253       84   True  ../input/rsna-bone-age/boneage-training-datase...
# 6049  8280      186   True  ../input/rsna-bone-age/boneage-training-datase...
# 3783  5769      156  False  ../input/rsna-bone-age/boneage-training-datase...
#
#       exists  gender  boneage_zscore
# 5124    True    male            84.0
# 6049    True    male           186.0
# 3783    True  female           156.0

# %%
age_df[['boneage', 'male', 'boneage_zscore']].hist(figsize = (10, 5))
age_df['boneage_category'] = pd.cut(age_df['boneage'], 10)

# %% [markdown]
# # 데이터 나누기(train,vaild,test)

# %%
from sklearn.model_selection import train_test_split
raw_train_df, valid_df = train_test_split(age_df, 
                                   test_size = 0.25, 
                                   random_state = 2018,
                                   stratify = age_df['boneage_category'])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0])
# Out:
# train 9458 validation 3153

# %%
train_df = raw_train_df.groupby(['boneage_category', 'male']).apply(lambda x: x.sample(500, replace = True)
                                                      ).reset_index(drop = True)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
train_df[['boneage', 'male']].hist(figsize = (10, 5))
# Out:
# New Data Size: 10000 Old Size: 9458
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3c53c2ddd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3c53c38e48>]],
#       dtype=object)

# %%
#augmentation
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import preprocess_input
IMG_SIZE = (384, 384) 
core_idg = ImageDataGenerator(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.15, 
                              width_shift_range = 0.15, 
                              rotation_range = 5, 
                              shear_range = 0.01,
                              fill_mode = 'nearest',
                              zoom_range=0.25,
                             preprocessing_function = preprocess_input)
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    base_dir = os.path.dirname(in_df[path_col].values[0])
    print('## Ignore next message from keras, values are replaced anyways')
    df_gen = img_data_gen.flow_from_directory(base_dir, 
                                     class_mode = 'sparse',
                                    **dflow_args)
    df_gen.filenames = in_df[path_col].values
    df_gen.classes = np.stack(in_df[y_col].values)
    df_gen.samples = in_df.shape[0]
    df_gen.n = in_df.shape[0]
    df_gen._set_index_array()
    df_gen.directory = '' 
    print('Reinserting dataframe: {} images'.format(in_df.shape[0]))
    return df_gen

# %%
train_gen = flow_from_dataframe(core_idg, train_df, 
                             path_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 32)

valid_gen = flow_from_dataframe(core_idg, valid_df, 
                             path_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 256)
test_X, test_Y = next(flow_from_dataframe(core_idg, 
                               valid_df, 
                             path_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1024)) # one big batch
# Out:
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 10000 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 3153 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 3153 images

# %%
t_x, t_y = next(train_gen)
fig, m_axs = plt.subplots(2, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -127, vmax = 127)
    c_ax.set_title('%2.0f months' % (c_y*boneage_div+boneage_mean))
    c_ax.axis('off')

# %% [markdown]
# **MODEL**

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, Input, Conv2D, multiply, LocallyConnected2D, Lambda
from keras.models import Model
in_lay = Input(t_x.shape[1:])
base_pretrained_model = VGG16(input_shape =  t_x.shape[1:], include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False
pt_depth = base_pretrained_model.get_output_shape_at(0)[-1]
pt_features = base_pretrained_model(in_lay)
from keras.layers import BatchNormalization
bn_features = BatchNormalization()(pt_features)

#custom

attn_layer = Conv2D(64, kernel_size = (3,3), padding = 'same', activation = 'relu')(bn_features)
attn_layer  = BatchNormalization()(bn_features)
attn_layer = Conv2D(16, kernel_size = (3,3), padding = 'same', activation = 'relu')(attn_layer)
attn_layer  = BatchNormalization()(attn_layer)
attn_layer = LocallyConnected2D(1, 
                                kernel_size = (1,1), 
                                padding = 'valid', 
                                activation = 'sigmoid')(attn_layer)
#합치기

up_c2_w = np.ones((1, 1, 1, pt_depth))
up_c2 = Conv2D(pt_depth, kernel_size = (1,1), padding = 'same', 
               activation = 'linear', use_bias = False, weights = [up_c2_w])
up_c2.trainable = False
attn_layer = up_c2(attn_layer)

mask_features = multiply([attn_layer, bn_features])
gap_features = GlobalAveragePooling2D()(mask_features)
gap_mask = GlobalAveragePooling2D()(attn_layer)
# to account for missing values from the attention model
gap = Lambda(lambda x: x[0]/x[1], name = 'RescaleGAP')([gap_features, gap_mask])
gap_dr = Dropout(0.5)(gap)
dr_steps = Dropout(0.25)(Dense(512, activation = 'relu')(gap_dr))
out_layer = Dense(1, activation = 'linear')(dr_steps) # linear is what 16bit did
bone_age_model = Model(inputs = [in_lay], outputs = [out_layer])
from keras.metrics import mean_absolute_error
def mae_months(in_gt, in_pred):
    return mean_absolute_error(boneage_div*in_gt, boneage_div*in_pred)

bone_age_model.compile(optimizer = 'adam', loss = 'mse',
                           metrics = [mae_months])

bone_age_model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 384, 384, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Model)                   (None, 12, 12, 512)  14714688    input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 12, 12, 512)  2048        vgg16[1][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 12, 12, 512)  2048        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 12, 12, 16)   73744       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# locally_connected2d_1 (LocallyC (None, 12, 12, 1)    2448        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 512)  512         locally_connected2d_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 12, 12, 512)  0           conv2d_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           multiply_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# RescaleGAP (Lambda)             (None, 512)          0           global_average_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           RescaleGAP[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            513         dropout_2[0][0]
# ==================================================================================================
# Total params: 15,058,721
# Trainable params: 341,441
# Non-trainable params: 14,717,280
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="preVGG16.hdf5".format('bone_age')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=5) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# /opt/conda/lib/python3.6/site-packages/Keras-2.1.5-py3.6.egg/keras/callbacks.py:919: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` insted.

# %%
history=bone_age_model.fit_generator(train_gen, 
                                  steps_per_epoch=50,
                                  validation_data = (test_X, test_Y), 
                                  epochs = 50, 
                                  callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 184s 4s/step - loss: 14888.3162 - mae_months: 104.8069 - val_loss: 6680.4594 - val_mae_months: 70.4275
#
# Epoch 00001: val_loss improved from inf to 6680.45937, saving model to preVGG16.hdf5
# Epoch 2/50
# 50/50 [==============================] - 164s 3s/step - loss: 2553.1441 - mae_months: 36.9838 - val_loss: 1024.9428 - val_mae_months: 24.5710
#
# Epoch 00002: val_loss improved from 6680.45937 to 1024.94279, saving model to preVGG16.hdf5
# Epoch 3/50
# 50/50 [==============================] - 160s 3s/step - loss: 1102.0998 - mae_months: 26.1308 - val_loss: 1041.1071 - val_mae_months: 25.5568
#
# Epoch 00003: val_loss did not improve
# Epoch 4/50
# 50/50 [==============================] - 156s 3s/step - loss: 1116.8247 - mae_months: 26.3402 - val_loss: 672.5531 - val_mae_months: 20.4152
#
# Epoch 00004: val_loss improved from 1024.94279 to 672.55315, saving model to preVGG16.hdf5
# Epoch 5/50
# 50/50 [==============================] - 144s 3s/step - loss: 931.2473 - mae_months: 23.8713 - val_loss: 613.4821 - val_mae_months: 19.5636
#
# Epoch 00005: val_loss improved from 672.55315 to 613.48209, saving model to preVGG16.hdf5
# Epoch 6/50
# 50/50 [==============================] - 151s 3s/step - loss: 844.1304 - mae_months: 22.5680 - val_loss: 671.4232 - val_mae_months: 20.3774
#
# Epoch 00006: val_loss did not improve
# Epoch 7/50
# 50/50 [==============================] - 139s 3s/step - loss: 856.6309 - mae_months: 23.1105 - val_loss: 629.9821 - val_mae_months: 19.8900
#
# Epoch 00007: val_loss did not improve
# Epoch 8/50
# 50/50 [==============================] - 136s 3s/step - loss: 827.2814 - mae_months: 22.3111 - val_loss: 554.6543 - val_mae_months: 18.7100
#
# Epoch 00008: val_loss improved from 613.48209 to 554.65428, saving model to preVGG16.hdf5
# Epoch 9/50
# 50/50 [==============================] - 136s 3s/step - loss: 709.2304 - mae_months: 20.9125 - val_loss: 539.0966 - val_mae_months: 18.4990
#
# Epoch 00009: val_loss improved from 554.65428 to 539.09658, saving model to preVGG16.hdf5
# Epoch 10/50
# 50/50 [==============================] - 138s 3s/step - loss: 732.0465 - mae_months: 21.1883 - val_loss: 583.0261 - val_mae_months: 19.1343
#
# Epoch 00010: val_loss did not improve
# Epoch 11/50
# 50/50 [==============================] - 139s 3s/step - loss: 669.5115 - mae_months: 19.8977 - val_loss: 522.6886 - val_mae_months: 18.0040
#
# Epoch 00011: val_loss improved from 539.09658 to 522.68858, saving model to preVGG16.hdf5
# Epoch 12/50
# 50/50 [==============================] - 135s 3s/step - loss: 692.7429 - mae_months: 20.4873 - val_loss: 558.9484 - val_mae_months: 18.4499
#
# Epoch 00012: val_loss did not improve
# Epoch 13/50
# 50/50 [==============================] - 133s 3s/step - loss: 673.8805 - mae_months: 20.1444 - val_loss: 539.8369 - val_mae_months: 18.4263
#
# Epoch 00013: val_loss did not improve
# Epoch 14/50
# 50/50 [==============================] - 133s 3s/step - loss: 649.3863 - mae_months: 19.6577 - val_loss: 462.1615 - val_mae_months: 17.0632
#
# Epoch 00014: val_loss improved from 522.68858 to 462.16146, saving model to preVGG16.hdf5
# Epoch 15/50
# 50/50 [==============================] - 133s 3s/step - loss: 675.3804 - mae_months: 20.1397 - val_loss: 446.6645 - val_mae_months: 16.8086
#
# Epoch 00015: val_loss improved from 462.16146 to 446.66451, saving model to preVGG16.hdf5
# Epoch 16/50
# 50/50 [==============================] - 133s 3s/step - loss: 587.2554 - mae_months: 19.0081 - val_loss: 441.2911 - val_mae_months: 16.6571
#
# Epoch 00016: val_loss improved from 446.66451 to 441.29113, saving model to preVGG16.hdf5
# Epoch 17/50
# 50/50 [==============================] - 135s 3s/step - loss: 568.5497 - mae_months: 18.5563 - val_loss: 437.3105 - val_mae_months: 16.5490
#
# Epoch 00017: val_loss improved from 441.29113 to 437.31049, saving model to preVGG16.hdf5
# Epoch 18/50
# 50/50 [==============================] - 134s 3s/step - loss: 555.9365 - mae_months: 18.4344 - val_loss: 447.3685 - val_mae_months: 16.8542
#
# Epoch 00018: val_loss did not improve
# Epoch 19/50
# 50/50 [==============================] - 135s 3s/step - loss: 516.2151 - mae_months: 17.7977 - val_loss: 444.1186 - val_mae_months: 16.7924
#
# Epoch 00019: val_loss did not improve
# Epoch 20/50
# 50/50 [==============================] - 133s 3s/step - loss: 528.6382 - mae_months: 17.6650 - val_loss: 481.3686 - val_mae_months: 17.4493
#
# Epoch 00020: val_loss did not improve
# Epoch 21/50
# 50/50 [==============================] - 134s 3s/step - loss: 521.9671 - mae_months: 17.9803 - val_loss: 414.5960 - val_mae_months: 16.2725
#
# Epoch 00021: val_loss improved from 437.31049 to 414.59598, saving model to preVGG16.hdf5
# Epoch 22/50
# 50/50 [==============================] - 134s 3s/step - loss: 560.9963 - mae_months: 18.4582 - val_loss: 503.7964 - val_mae_months: 17.8161
#
# Epoch 00022: val_loss did not improve
# Epoch 23/50
# 50/50 [==============================] - 134s 3s/step - loss: 522.5248 - mae_months: 17.8035 - val_loss: 411.4688 - val_mae_months: 16.1776
#
# Epoch 00023: val_loss improved from 414.59598 to 411.46875, saving model to preVGG16.hdf5
# Epoch 24/50
# 50/50 [==============================] - 134s 3s/step - loss: 519.0764 - mae_months: 18.1283 - val_loss: 406.3887 - val_mae_months: 15.9103
#
# Epoch 00024: val_loss improved from 411.46875 to 406.38870, saving model to preVGG16.hdf5
# Epoch 25/50
# 50/50 [==============================] - 133s 3s/step - loss: 525.4033 - mae_months: 17.8045 - val_loss: 393.5182 - val_mae_months: 15.7669
#
# Epoch 00025: val_loss improved from 406.38870 to 393.51823, saving model to preVGG16.hdf5
# Epoch 26/50
# 50/50 [==============================] - 134s 3s/step - loss: 509.9344 - mae_months: 17.8829 - val_loss: 422.3929 - val_mae_months: 16.1551
#
# Epoch 00026: val_loss did not improve
# Epoch 27/50
# 50/50 [==============================] - 134s 3s/step - loss: 453.7555 - mae_months: 16.6797 - val_loss: 399.2891 - val_mae_months: 15.6985
#
# Epoch 00027: val_loss did not improve
# Epoch 28/50
# 50/50 [==============================] - 134s 3s/step - loss: 516.6494 - mae_months: 17.5949 - val_loss: 494.6651 - val_mae_months: 17.5895
#
# Epoch 00028: val_loss did not improve
# Epoch 29/50
# 50/50 [==============================] - 133s 3s/step - loss: 483.2901 - mae_months: 17.1695 - val_loss: 374.3016 - val_mae_months: 15.3709
#
# Epoch 00029: val_loss improved from 393.51823 to 374.30161, saving model to preVGG16.hdf5
# Epoch 30/50
# 50/50 [==============================] - 135s 3s/step - loss: 438.1935 - mae_months: 16.3642 - val_loss: 373.8090 - val_mae_months: 15.1957
#
# Epoch 00030: val_loss improved from 374.30161 to 373.80896, saving model to preVGG16.hdf5
# Epoch 31/50
# 50/50 [==============================] - 133s 3s/step - loss: 479.7269 - mae_months: 17.1452 - val_loss: 403.2867 - val_mae_months: 16.0218
#
# Epoch 00031: val_loss did not improve
# Epoch 32/50
# 50/50 [==============================] - 133s 3s/step - loss: 436.7255 - mae_months: 16.3188 - val_loss: 370.5648 - val_mae_months: 15.3449
#
# Epoch 00032: val_loss improved from 373.80896 to 370.56479, saving model to preVGG16.hdf5
# Epoch 33/50
# 50/50 [==============================] - 133s 3s/step - loss: 451.9384 - mae_months: 16.7405 - val_loss: 392.3184 - val_mae_months: 15.6622
#
# Epoch 00033: val_loss did not improve
# Epoch 34/50
# 50/50 [==============================] - 135s 3s/step - loss: 445.4254 - mae_months: 16.3437 - val_loss: 393.5361 - val_mae_months: 15.7418
#
# Epoch 00034: val_loss did not improve
# Epoch 35/50
# 50/50 [==============================] - 135s 3s/step - loss: 462.2565 - mae_months: 16.6376 - val_loss: 363.0169 - val_mae_months: 15.0133
#
# Epoch 00035: val_loss improved from 370.56479 to 363.01686, saving model to preVGG16.hdf5
# Epoch 36/50
# 50/50 [==============================] - 135s 3s/step - loss: 452.5906 - mae_months: 16.6916 - val_loss: 392.6408 - val_mae_months: 15.8699
#
# Epoch 00036: val_loss did not improve
# Epoch 37/50
# 50/50 [==============================] - 137s 3s/step - loss: 457.0408 - mae_months: 16.9107 - val_loss: 353.3516 - val_mae_months: 14.9356
#
# Epoch 00037: val_loss improved from 363.01686 to 353.35156, saving model to preVGG16.hdf5
# Epoch 38/50
# 50/50 [==============================] - 137s 3s/step - loss: 431.3362 - mae_months: 16.2579 - val_loss: 340.6238 - val_mae_months: 14.6825
#
# Epoch 00038: val_loss improved from 353.35156 to 340.62379, saving model to preVGG16.hdf5
# Epoch 39/50
# 50/50 [==============================] - 138s 3s/step - loss: 436.1906 - mae_months: 16.2065 - val_loss: 445.4906 - val_mae_months: 16.8726
#
# Epoch 00039: val_loss did not improve
# Epoch 40/50
# 50/50 [==============================] - 138s 3s/step - loss: 406.2752 - mae_months: 15.6553 - val_loss: 393.0268 - val_mae_months: 15.8086
#
# Epoch 00040: val_loss did not improve
# Epoch 41/50
# 50/50 [==============================] - 138s 3s/step - loss: 405.6848 - mae_months: 15.7423 - val_loss: 342.4108 - val_mae_months: 14.5727
#
# Epoch 00041: val_loss did not improve
# Epoch 42/50
# 50/50 [==============================] - 139s 3s/step - loss: 425.8821 - mae_months: 16.2072 - val_loss: 385.8098 - val_mae_months: 15.5460
#
# Epoch 00042: val_loss did not improve
# Epoch 43/50
# 50/50 [==============================] - 137s 3s/step - loss: 422.6871 - mae_months: 16.0425 - val_loss: 328.9623 - val_mae_months: 14.3779
#
# Epoch 00043: val_loss improved from 340.62379 to 328.96227, saving model to preVGG16.hdf5
# Epoch 44/50
# 50/50 [==============================] - 137s 3s/step - loss: 399.3561 - mae_months: 15.5988 - val_loss: 319.2940 - val_mae_months: 14.2414
#
# Epoch 00044: val_loss improved from 328.96227 to 319.29398, saving model to preVGG16.hdf5
# Epoch 45/50
# 50/50 [==============================] - 138s 3s/step - loss: 420.0892 - mae_months: 16.0969 - val_loss: 337.3716 - val_mae_months: 14.5737
#
# Epoch 00045: val_loss did not improve
# Epoch 46/50
# 50/50 [==============================] - 139s 3s/step - loss: 417.6536 - mae_months: 15.9275 - val_loss: 323.3737 - val_mae_months: 14.2539
#
# Epoch 00046: val_loss did not improve
# Epoch 47/50
# 50/50 [==============================] - 140s 3s/step - loss: 411.5193 - mae_months: 15.9215 - val_loss: 321.5695 - val_mae_months: 14.1950
#
# Epoch 00047: val_loss did not improve
# Epoch 48/50
# 50/50 [==============================] - 138s 3s/step - loss: 415.7251 - mae_months: 15.8648 - val_loss: 340.2137 - val_mae_months: 14.6192
#
# Epoch 00048: val_loss did not improve
# Epoch 49/50
# 50/50 [==============================] - 137s 3s/step - loss: 364.3051 - mae_months: 15.0864 - val_loss: 354.9651 - val_mae_months: 14.9157
#
# Epoch 00049: val_loss did not improve

# %%
def plot_it(history):
    '''function to plot training and validation error'''
    fig, ax = plt.subplots( figsize=(20,10))
    ax.plot(history.history['mae_months'])
    ax.plot(history.history['val_mae_months'])
    plt.title('Model Error')
    plt.ylabel('error')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    ax.grid(color='black')
    plt.show()

# %%
import matplotlib.pyplot as plt
plot_it(history)

# %%
bone_age_model.save('preVGG16(30).h5')

# %%
# load the best version of the model
bone_age_model.load_weights(weight_path)

# %% [markdown]
# # 확인

# %%
# get the attention layer since it is the only one with a single output dim
for attn_layer in bone_age_model.layers:
    c_shape = attn_layer.get_output_shape_at(0)
    if len(c_shape)==4:
        if c_shape[-1]==1:
            print(attn_layer)
            break
# Out:
# <keras.layers.local.LocallyConnected2D object at 0x7f3c2c0b3080>

# %%
import keras.backend as K
rand_idx = np.random.choice(range(len(test_X)), size = 6)
attn_func = K.function(inputs = [bone_age_model.get_input_at(0), K.learning_phase()],
           outputs = [attn_layer.get_output_at(0)]
          )
fig, m_axs = plt.subplots(len(rand_idx), 2, figsize = (8, 4*len(rand_idx)))
[c_ax.axis('off') for c_ax in m_axs.flatten()]
for c_idx, (img_ax, attn_ax) in zip(rand_idx, m_axs):
    cur_img = test_X[c_idx:(c_idx+1)]
    attn_img = attn_func([cur_img, 0])[0]
    img_ax.imshow(cur_img[0,:,:,0], cmap = 'bone')
    attn_ax.imshow(attn_img[0, :, :, 0], cmap = 'viridis', 
                   vmin = 0, vmax = 1, 
                   interpolation = 'lanczos')
    real_age = boneage_div*test_Y[c_idx]+boneage_mean
    img_ax.set_title('Hand Image\nAge:%2.2fY' % (real_age/12))
    pred_age = boneage_div*bone_age_model.predict(cur_img)+boneage_mean
    attn_ax.set_title('Attention Map\nPred:%2.2fY' % (pred_age/12))
fig.savefig('attention_map.png', dpi = 300)

# %% [markdown]
# # 시각화(회귀)

# %%
pred_Y = boneage_div*bone_age_model.predict(test_X, batch_size = 32, verbose = True)+boneage_mean
test_Y_months = boneage_div*test_Y+boneage_mean
# Out:
# 1024/1024 [==============================] - 9s 9ms/step

# %%
fig, ax1 = plt.subplots(1,1, figsize = (6,6))
ax1.plot(test_Y_months, pred_Y, 'r.', label = 'predictions')
ax1.plot(test_Y_months, test_Y_months, 'b-', label = 'actual')
ax1.legend()
ax1.set_xlabel('Actual Age (Months)')
ax1.set_ylabel('Predicted Age (Months)')
# Out:
# Text(0,0.5,'Predicted Age (Months)')

# %%
ord_idx = np.argsort(test_Y)
ord_idx = ord_idx[np.linspace(0, len(ord_idx)-1, 8).astype(int)] # take 8 evenly spaced ones
fig, m_axs = plt.subplots(4, 2, figsize = (16, 32))
for (idx, c_ax) in zip(ord_idx, m_axs.flatten()):
    c_ax.imshow(test_X[idx, :,:,0], cmap = 'bone')
    
    c_ax.set_title('Age: %2.1fY\nPredicted Age: %2.1fY' % (test_Y_months[idx]/12.0, 
                                                           pred_Y[idx]/12.0))
    c_ax.axis('off')
fig.savefig('trained_img_predictions.png', dpi = 300)
